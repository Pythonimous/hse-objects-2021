# %%
from google.colab import drive
import os

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !cp gdrive/MyDrive/yelp_task/yelp_photos.tar yelp_photos.tar

# %%
# !tar -xf yelp_photos.tar

# %%
# !rm yelp_photos.tar

# %%
len(os.listdir('photos'))
# Out:
# 199999

# %%
from __future__ import print_function
from __future__ import division

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

# %%
import numpy as np
import pandas as pd
import torchvision
from torchvision import datasets, models, transforms
from PIL import Image
import matplotlib.pyplot as plt

# %%
import time
import os
import copy
import tarfile

# %%
print("PyTorch Version: ",torch.__version__)
print("Torchvision Version: ",torchvision.__version__)
# Out:
# PyTorch Version:  1.8.1+cu101
# Torchvision Version:  0.9.1+cu101

# %%
model_name = "alexnet"
photo_tar = tarfile.open("./gdrive/MyDrive/yelp_task/yelp_photos.tar")
csv_dir = "./gdrive/MyDrive/yelp_task/yelp_data/business_restaurant"
